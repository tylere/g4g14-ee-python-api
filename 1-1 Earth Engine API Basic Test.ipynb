# %% [markdown]
# # Initialize Earth Engine.

# %%
import ee

# Initialize the Earth Engine object, using authentication credentials
# that are saved on the server.
ee.Initialize()

# %% [markdown]
# # Image objects

# %% [markdown]
# Display a list of methods for Earth Engine Image objects.

# %%
image_object = ee.Image()
[method for method in dir(image_object) if not method.startswith('_')]
# Out:
# ['And',
#  'Not',
#  'Or',
#  'abs',
#  'acos',
#  'add',
#  'addBands',
#  'args',
#  'arrayAccum',
#  'arrayFlatten',
#  'arrayGet',
#  'arrayLengths',
#  'arrayMask',
#  'arrayProject',
#  'arrayReduce',
#  'arrayRepeat',
#  'arraySlice',
#  'arraySort',
#  'arrayTranspose',
#  'asin',
#  'atan',
#  'atan2',
#  'bandNames',
#  'bandTypes',
#  'bilinearSample',
#  'bitwiseAnd',
#  'bitwiseNot',
#  'bitwiseOr',
#  'bitwiseXor',
#  'bitwise_and',
#  'bitwise_not',
#  'bitwise_or',
#  'bitwise_xor',
#  'byte',
#  'cast',
#  'cat',
#  'ceil',
#  'clamp',
#  'classify',
#  'clip',
#  'combine_',
#  'connectedComponents',
#  'connectedPixelCount',
#  'constant',
#  'convolve',
#  'copyProperties',
#  'cos',
#  'cosh',
#  'derivative',
#  'distance',
#  'divide',
#  'double',
#  'encode',
#  'entropy',
#  'eq',
#  'exp',
#  'expression',
#  'first',
#  'firstNonZero',
#  'first_nonzero',
#  'float',
#  'floor',
#  'focal_max',
#  'focal_median',
#  'focal_min',
#  'focal_mode',
#  'freeze',
#  'func',
#  'geometry',
#  'get',
#  'getDownloadUrl',
#  'getInfo',
#  'getMapId',
#  'getThumbUrl',
#  'glcmTexture',
#  'gt',
#  'gte',
#  'hsvtorgb',
#  'hypot',
#  'id',
#  'initialize',
#  'int',
#  'int16',
#  'int32',
#  'int64',
#  'int8',
#  'interpolate',
#  'isVariable',
#  'leftShift',
#  'left_shift',
#  'load',
#  'log',
#  'log10',
#  'long',
#  'lt',
#  'lte',
#  'mask',
#  'matrixDeterminant',
#  'matrixDiagonal',
#  'matrixFnorm',
#  'matrixIdentity',
#  'matrixInverse',
#  'matrixMultiply',
#  'matrixPseudoInverse',
#  'matrixSolve',
#  'matrixToDiag',
#  'matrixTrace',
#  'matrixTranspose',
#  'max',
#  'metadata',
#  'min',
#  'mod',
#  'multiply',
#  'name',
#  'neighborhoodToBands',
#  'neq',
#  'normalizedDifference',
#  'paint',
#  'parseExpression',
#  'pixelArea',
#  'pixelLonLat',
#  'polynomial',
#  'pow',
#  'projection',
#  'randomVisualizer',
#  'reduce',
#  'reduceNeighborhood',
#  'reduceRegion',
#  'reduceRegions',
#  'reduceToVectors',
#  'remap',
#  'reproject',
#  'reset',
#  'rgb',
#  'rgbtohsv',
#  'rightShift',
#  'right_shift',
#  'round',
#  'select',
#  'serialize',
#  'set',
#  'setMulti',
#  'short',
#  'sin',
#  'sinh',
#  'sldStyle',
#  'slice',
#  'sqrt',
#  'stats',
#  'subtract',
#  'tan',
#  'tanh',
#  'toArray',
#  'toByte',
#  'toDouble',
#  'toFloat',
#  'toInt',
#  'toInt16',
#  'toInt32',
#  'toInt64',
#  'toInt8',
#  'toLong',
#  'toShort',
#  'toUint16',
#  'toUint32',
#  'toUint8',
#  'trainClassifier',
#  'uint16',
#  'uint32',
#  'uint8',
#  'unitScale',
#  'unmix',
#  'varName',
#  'visualize',
#  'where',
#  'zeroCrossing']

# %%
image = ee.Image('srtm90_v4')

# %% [markdown]
# Display an Earth Engine generated image, using IPython's ability to render an image obtained from a URL.

# %%
from IPython.display import Image
Image(url=image.getThumbUrl({'min':0, 'max':3000}))
# Out:
# <img src="https://earthengine.googleapis.com//api/thumb?thumbid=d6216bca1808eab68b0dd18bca0d320e&token=a7499527579f2b00cbdb0789328311cf"/>
